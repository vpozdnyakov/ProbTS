# %%
import pandas as pd

# %%
ver = 18
metrics = pd.read_csv(f'logs/lightning_logs/version_{ver}/metrics.csv', index_col='step')
metrics['val_CRPS'].dropna().plot(grid=True);

# %%
metrics['train_loss'].dropna().plot(grid=True);
